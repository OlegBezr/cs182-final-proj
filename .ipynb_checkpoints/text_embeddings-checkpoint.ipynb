# %%
# !pip install -U sentence-transformers
# Out:
# Collecting sentence-transformers
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      |████████████████████████████████| 85 kB 2.4 MB/s eta 0:00:01
# Collecting transformers<5.0.0,>=4.6.0
#   Downloading transformers-4.35.2-py3-none-any.whl (7.9 MB)
#      |████████████████████████████████| 7.9 MB 4.6 MB/s eta 0:00:01     |█████████████████████████████▎  | 7.2 MB 4.5 MB/s eta 0:00:01
# Requirement already satisfied: tqdm in /Users/amralazali/opt/anaconda3/lib/python3.9/site-packages (from sentence-transformers) (4.64.0)
# Requirement already satisfied: torch>=1.6.0 in /Users/amralazali/opt/anaconda3/lib/python3.9/site-packages (from sentence-transformers) (2.1.0)
# Requirement already satisfied: torchvision in /Users/amralazali/opt/anaconda3/lib/python3.9/site-packages (from sentence-transformers) (0.16.0)
# Requirement already satisfied: numpy in /Users/amralazali/opt/anaconda3/lib/python3.9/site-packages (from sentence-transformers) (1.26.0)
# Requirement already satisfied: scikit-learn in /Users/amralazali/opt/anaconda3/lib/python3.9/site-packages (from sentence-transformers) (1.0.2)
# Requirement already satisfied: scipy in /Users/amralazali/opt/anaconda3/lib/python3.9/site-packages (from sentence-transformers) (1.7.3)
# Requirement already satisfied: nltk in /Users/amralazali/opt/anaconda3/lib/python3.9/site-packages (from sentence-transformers) (3.7)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.99-cp39-cp39-macosx_10_9_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 6.7 MB/s eta 0:00:01
# Collecting huggingface-hub>=0.4.0
#   Downloading huggingface_hub-0.19.4-py3-none-any.whl (311 kB)
#      |████████████████████████████████| 311 kB 8.8 MB/s eta 0:00:01
# Requirement already satisfied: pyyaml>=5.1 in /Users/amralazali/opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (6.0)
# Requirement already satisfied: requests in /Users/amralazali/opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2.27.1)
# Requirement already satisfied: filelock in /Users/amralazali/opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/amralazali/opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (4.1.1)
# Requirement already satisfied: packaging>=20.9 in /Users/amralazali/opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (21.3)
# Collecting fsspec>=2023.5.0
#   Downloading fsspec-2023.12.0-py3-none-any.whl (168 kB)
#      |████████████████████████████████| 168 kB 5.8 MB/s eta 0:00:01
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/amralazali/opt/anaconda3/lib/python3.9/site-packages (from packaging>=20.9->huggingface-hub>=0.4.0->sentence-transformers) (3.0.4)
# Requirement already satisfied: sympy in /Users/amralazali/opt/anaconda3/lib/python3.9/site-packages (from torch>=1.6.0->sentence-transformers) (1.10.1)
# Requirement already satisfied: networkx in /Users/amralazali/opt/anaconda3/lib/python3.9/site-packages (from torch>=1.6.0->sentence-transformers) (2.7.1)
# Requirement already satisfied: jinja2 in /Users/amralazali/opt/anaconda3/lib/python3.9/site-packages (from torch>=1.6.0->sentence-transformers) (3.1.2)
# Collecting tokenizers<0.19,>=0.14
#   Downloading tokenizers-0.15.0-cp39-cp39-macosx_10_7_x86_64.whl (2.6 MB)
#      |████████████████████████████████| 2.6 MB 3.9 MB/s eta 0:00:01
# Collecting safetensors>=0.3.1
#   Downloading safetensors-0.4.1-cp39-cp39-macosx_10_7_x86_64.whl (441 kB)
#      |████████████████████████████████| 441 kB 9.1 MB/s eta 0:00:01
# Requirement already satisfied: regex!=2019.12.17 in /Users/amralazali/opt/anaconda3/lib/python3.9/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2022.3.15)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/amralazali/opt/anaconda3/lib/python3.9/site-packages (from jinja2->torch>=1.6.0->sentence-transformers) (2.1.2)
# Requirement already satisfied: click in /Users/amralazali/opt/anaconda3/lib/python3.9/site-packages (from nltk->sentence-transformers) (8.0.4)
# Requirement already satisfied: joblib in /Users/amralazali/opt/anaconda3/lib/python3.9/site-packages (from nltk->sentence-transformers) (1.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/amralazali/opt/anaconda3/lib/python3.9/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/amralazali/opt/anaconda3/lib/python3.9/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/amralazali/opt/anaconda3/lib/python3.9/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/amralazali/opt/anaconda3/lib/python3.9/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/amralazali/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn->sentence-transformers) (2.2.0)
# Collecting numpy
#   Downloading numpy-1.22.4-cp39-cp39-macosx_10_15_x86_64.whl (17.7 MB)
#      |████████████████████████████████| 17.7 MB 2.3 MB/s eta 0:00:01
# Requirement already satisfied: mpmath>=0.19 in /Users/amralazali/opt/anaconda3/lib/python3.9/site-packages (from sympy->torch>=1.6.0->sentence-transformers) (1.2.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/amralazali/opt/anaconda3/lib/python3.9/site-packages (from torchvision->sentence-transformers) (9.0.1)
# Building wheels for collected packages: sentence-transformers
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125940 sha256=cd9f623a058ac20436ba690fc579d3631371cfc0f2873fed6e58ff686652e01a
#   Stored in directory: /Users/amralazali/Library/Caches/pip/wheels/71/67/06/162a3760c40d74dd40bc855d527008d26341c2b0ecf3e8e11f
# Successfully built sentence-transformers
# Installing collected packages: fsspec, numpy, huggingface-hub, tokenizers, safetensors, transformers, sentencepiece, sentence-transformers
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2022.2.0
#     Uninstalling fsspec-2022.2.0:
#       Successfully uninstalled fsspec-2022.2.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.0
#     Uninstalling numpy-1.26.0:
#       Successfully uninstalled numpy-1.26.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# daal4py 2021.5.0 requires daal==2021.4.0, which is not installed.
# tensorflow 2.14.0 requires numpy>=1.23.5, but you have numpy 1.22.4 which is incompatible.
# numba 0.55.1 requires numpy<1.22,>=1.18, but you have numpy 1.22.4 which is incompatible.
# Successfully installed fsspec-2023.12.0 huggingface-hub-0.19.4 numpy-1.22.4 safetensors-0.4.1 sentence-transformers-2.2.2 sentencepiece-0.1.99 tokenizers-0.15.0 transformers-4.35.2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sentence_transformers import SentenceTransformer
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# # Toy Example

# %%
model = SentenceTransformer('all-MiniLM-L6-v2')
sentences = ['This framework generates embeddings for each input sentence',
    'Sentences are passed as a list of string.',
    'The quick brown fox jumps over the lazy dog.']
embeddings = model.encode(sentences)

# %%
embeddings
# Out:
# array([[-0.01371735, -0.04285153, -0.01562862, ...,  0.10017824,
#          0.12365722, -0.0422967 ],
#        [ 0.05645244,  0.0550024 ,  0.03137964, ...,  0.06650873,
#          0.08491519, -0.03328491],
#        [ 0.04393354,  0.05893443,  0.04817836, ...,  0.0521628 ,
#          0.05610655,  0.10206389]], dtype=float32)

# %% [markdown]
# # Creating embeddings for our training data

# %%
data_df = pd.read_csv('combined_data.csv')

# %%
data_with_embeddings = data_df.copy()
text_embedding = model.encode(list(data_df['text']))

# %%
text_embedding.shape
# Out:
# (3682, 384)

# %%
text_embedding
# Out:
# array([[ 0.00704144, -0.03013029, -0.04435365, ..., -0.0544406 ,
#          0.05921537,  0.00155115],
#        [ 0.10417518, -0.00156555, -0.02994591, ..., -0.03375116,
#         -0.00558799, -0.00082396],
#        [ 0.00075028,  0.03847636, -0.1037306 , ..., -0.0023817 ,
#          0.1151488 ,  0.00127083],
#        ...,
#        [ 0.05096078, -0.00226238,  0.02425114, ...,  0.00428435,
#         -0.00899091,  0.07252097],
#        [ 0.03663088,  0.04196699, -0.01943851, ...,  0.01929659,
#         -0.06609503, -0.00291118],
#        [ 0.03821041,  0.09012372, -0.00053149, ..., -0.02986898,
#          0.01551143, -0.07037634]], dtype=float32)

# %%
data_with_embeddings['embeddings'] = text_embedding.tolist()

# %%
data_with_embeddings.to_csv('combined_data_with_embeddings.csv')

# %% [markdown]
# # PCA analysis

# %%
expanded_columns = pd.DataFrame(data_with_embeddings['embeddings'].tolist(), columns=[f'X{i}' for i in range(len(data_with_embeddings['embeddings'][0]))])
data_with_embeddings_expanded = pd.concat([data_with_embeddings, expanded_columns], axis= 1)

# %%
data_with_embeddings_expanded_truncated = data_with_embeddings_expanded[[f'X{i}' for i in range(len(data_with_embeddings['embeddings'][0]))] + ['type']]

# %%
data_with_embeddings_expanded_truncated
# Out:
#             X0        X1        X2        X3        X4        X5        X6  \
# 0     0.007041 -0.030130 -0.044354 -0.016915  0.058667  0.034401 -0.100423
# 1     0.104175 -0.001566 -0.029946 -0.010663  0.017916  0.029785 -0.076181
# 2     0.000750  0.038476 -0.103731  0.037185  0.070729  0.029850 -0.099637
# 3     0.007955  0.058384  0.073151  0.018502  0.091555 -0.008293  0.065197
# 4     0.043323 -0.046877  0.007786  0.017373  0.006143  0.009960 -0.106317
# ...        ...       ...       ...       ...       ...       ...       ...
# 3677  0.050388  0.034596  0.078191 -0.014842  0.101741 -0.058550  0.010465
# 3678  0.095195  0.040634  0.013533  0.042913 -0.037288  0.006045 -0.019562
# 3679  0.050961 -0.002262  0.024251  0.097738  0.065581  0.046830 -0.050065
# 3680  0.036631  0.041967 -0.019439  0.036394  0.012457 -0.040488 -0.028249
# 3681  0.038210  0.090124 -0.000531 -0.016956  0.066821 -0.004163  0.032094
#
#             X7        X8        X9  ...      X375      X376      X377  \
# 0    -0.071921 -0.032756  0.018937  ...  0.056485  0.004152  0.011612
# 1    -0.047158  0.015871  0.000117  ...  0.045490  0.027277  0.037310
# 2    -0.059078 -0.070012  0.110827  ... -0.011829  0.071493 -0.047784
# 3    -0.038102 -0.088555 -0.048625  ... -0.096781  0.019590 -0.017678
# 4    -0.058113 -0.067291 -0.037846  ... -0.016851  0.048594  0.002650
# ...        ...       ...       ...  ...       ...       ...       ...
# 3677 -0.012632  0.021008 -0.088345  ... -0.035136 -0.021526  0.002684
# 3678 -0.133432 -0.015102 -0.092814  ... -0.030161  0.053550 -0.063575
# 3679 -0.046077  0.006282  0.044364  ...  0.014369 -0.031429 -0.042181
# 3680 -0.107045 -0.062857  0.037033  ... -0.132220  0.057853 -0.059903
# 3681 -0.065701  0.061145  0.054256  ...  0.021627 -0.065556 -0.014055
#
#           X378      X379      X380      X381      X382      X383    type
# 0     0.031171  0.070559  0.054114 -0.054441  0.059215  0.001551  center
# 1     0.026161  0.069467 -0.004642 -0.033751 -0.005588 -0.000824    left
# 2     0.025679  0.076568  0.053040 -0.002382  0.115149  0.001271   right
# 3    -0.074056 -0.045598 -0.037046 -0.029334  0.016569  0.042236    left
# 4    -0.025597  0.009103 -0.012812 -0.021666  0.067312  0.011962   right
# ...        ...       ...       ...       ...       ...       ...     ...
# 3677  0.062899  0.014527 -0.006232  0.031586  0.079083 -0.048447    left
# 3678  0.025306 -0.022557  0.017764  0.044573 -0.028769 -0.004294     NaN
# 3679 -0.042261  0.013516  0.028590  0.004284 -0.008991  0.072521     NaN
# 3680  0.032564 -0.088004  0.046937  0.019297 -0.066095 -0.002911     NaN
# 3681 -0.002359  0.037800  0.062847 -0.029869  0.015511 -0.070376     NaN
#
# [3682 rows x 385 columns]

# %%
center_embeddings = data_with_embeddings_expanded_truncated[data_with_embeddings_expanded_truncated['type']=='center']
right_embeddings = data_with_embeddings_expanded_truncated[data_with_embeddings_expanded_truncated['type'] == 'right']
left_embeddings = data_with_embeddings_expanded_truncated[data_with_embeddings_expanded_truncated['type']=='left']

# %%
center_embeddings
# Out:
#             X0        X1        X2        X3        X4        X5        X6  \
# 0     0.007041 -0.030130 -0.044354 -0.016915  0.058667  0.034401 -0.100423
# 5    -0.022851  0.007856  0.013187 -0.001340  0.123223  0.045272  0.068733
# 8     0.035141 -0.036666 -0.001163 -0.002841  0.044225 -0.003311 -0.055538
# 17    0.003931  0.042187  0.128660  0.009664  0.028284 -0.022104  0.004893
# 19    0.061667  0.000966 -0.031503  0.066022  0.046642  0.105832  0.026858
# ...        ...       ...       ...       ...       ...       ...       ...
# 3625  0.034042  0.010349 -0.049296  0.048924  0.015843  0.047943  0.029442
# 3638  0.017933  0.038221  0.080240 -0.017855  0.014864 -0.039633  0.009735
# 3639  0.061735  0.077295  0.032443 -0.090068  0.072253  0.036361  0.018642
# 3650 -0.007028  0.140387 -0.031116  0.021637 -0.077028  0.007926  0.092987
# 3659 -0.071140  0.007851  0.004624 -0.034465  0.015566 -0.005315  0.126370
#
#             X7        X8        X9  ...      X375      X376      X377  \
# 0    -0.071921 -0.032756  0.018937  ...  0.056485  0.004152  0.011612
# 5     0.073309 -0.003106  0.097606  ...  0.011930 -0.079572 -0.039002
# 8    -0.073518  0.025240 -0.052999  ... -0.019099  0.058132 -0.071332
# 17   -0.044707  0.047454 -0.039734  ...  0.103595  0.036306 -0.051854
# 19   -0.032538  0.007044 -0.028047  ...  0.058648  0.050563  0.023688
# ...        ...       ...       ...  ...       ...       ...       ...
# 3625 -0.042356 -0.044982 -0.070646  ...  0.106159  0.063013 -0.052136
# 3638 -0.001002 -0.065782 -0.047231  ... -0.107203 -0.072108  0.021692
# 3639 -0.031543  0.061832  0.041081  ...  0.014073 -0.041122 -0.038077
# 3650 -0.066943  0.039499 -0.032581  ... -0.114163  0.040168  0.009158
# 3659 -0.024148 -0.057086 -0.031098  ...  0.024771 -0.042800 -0.008623
#
#           X378      X379      X380      X381      X382      X383    type
# 0     0.031171  0.070559  0.054114 -0.054441  0.059215  0.001551  center
# 5     0.060738 -0.037225  0.117596 -0.024066  0.067422  0.148397  center
# 8    -0.002137 -0.026079  0.053747  0.033268  0.112612  0.042738  center
# 17    0.015941  0.025386  0.009088  0.020265 -0.063742  0.050607  center
# 19   -0.014384 -0.006047  0.010739  0.039473  0.034189 -0.025969  center
# ...        ...       ...       ...       ...       ...       ...     ...
# 3625 -0.080917  0.019703  0.007190 -0.031549  0.020722 -0.009567  center
# 3638 -0.085258 -0.086258  0.035486 -0.004810  0.048264 -0.035154  center
#
# [997 rows x 385 columns]

# %%
left_embeddings
# Out:
#             X0        X1        X2        X3        X4        X5        X6  \
# 1     0.104175 -0.001566 -0.029946 -0.010663  0.017916  0.029785 -0.076181
# 3     0.007955  0.058384  0.073151  0.018502  0.091555 -0.008293  0.065197
# 6     0.039226  0.020489  0.089406  0.065009  0.071163 -0.016974 -0.032156
# 7     0.081141  0.009010  0.096251  0.054100  0.025478 -0.034839 -0.036252
# 9     0.087889  0.004612  0.001581 -0.016101  0.010505 -0.050067 -0.006745
# ...        ...       ...       ...       ...       ...       ...       ...
# 3648  0.030402 -0.028422  0.008369 -0.058104 -0.005127 -0.038701 -0.013883
# 3653  0.096554 -0.059083  0.057424  0.015526  0.069842  0.000169  0.010317
# 3662 -0.059014  0.004416  0.080582 -0.012690 -0.053463 -0.041907  0.045866
# 3669  0.122355  0.038885  0.016533 -0.024177  0.009299 -0.023916 -0.028264
# 3677  0.050388  0.034596  0.078191 -0.014842  0.101741 -0.058550  0.010465
#
#             X7        X8        X9  ...      X375      X376      X377  \
# 1    -0.047158  0.015871  0.000117  ...  0.045490  0.027277  0.037310
# 3    -0.038102 -0.088555 -0.048625  ... -0.096781  0.019590 -0.017678
# 6    -0.088122 -0.087703  0.011463  ... -0.029444  0.018134 -0.009261
# 7    -0.103552 -0.011449 -0.064127  ... -0.025710 -0.031035 -0.030292
# 9    -0.025915  0.062736  0.035942  ... -0.000365  0.022967 -0.040287
# ...        ...       ...       ...  ...       ...       ...       ...
# 3648 -0.035315 -0.010761 -0.053812  ... -0.015953  0.058666 -0.013251
# 3653  0.024999 -0.035954 -0.058370  ...  0.049375  0.017520  0.005715
# 3662  0.008029 -0.019575 -0.102892  ...  0.040589  0.020871 -0.010881
# 3669 -0.081241 -0.033877 -0.050398  ...  0.015291  0.017340  0.060757
# 3677 -0.012632  0.021008 -0.088345  ... -0.035136 -0.021526  0.002684
#
#           X378      X379      X380      X381      X382      X383  type
# 1     0.026161  0.069467 -0.004642 -0.033751 -0.005588 -0.000824  left
# 3    -0.074056 -0.045598 -0.037046 -0.029334  0.016569  0.042236  left
# 6    -0.008554 -0.038928 -0.028928  0.039473 -0.071205  0.035897  left
# 7     0.036764 -0.061803  0.018734  0.002975 -0.020683  0.030093  left
# 9    -0.042998 -0.048260  0.042847 -0.118817  0.077475 -0.010794  left
# ...        ...       ...       ...       ...       ...       ...   ...
# 3648 -0.022942 -0.048608  0.034258 -0.131748  0.064069  0.007697  left
# 3653 -0.081533 -0.002157  0.009388 -0.051632  0.137290  0.080732  left
# 3662 -0.055506 -0.082307 -0.001281  0.086921  0.047329  0.030392  left
# 3669  0.036481  0.000042  0.125216 -0.003695  0.131495  0.095487  left
# 3677  0.062899  0.014527 -0.006232  0.031586  0.079083 -0.048447  left
#
# [994 rows x 385 columns]

# %%
import pandas as pd
from sklearn.decomposition import PCA
def apply_pca(df, n_components=2):
    """
    Perform PCA on the given DataFrame and return a new DataFrame with reduced dimensions.

    Parameters:
    - df (pd.DataFrame): The input DataFrame.
    - n_components (int): The number of components to retain after PCA.

    Returns:
    - pd.DataFrame: A new DataFrame with reduced dimensions.
    """
    # Extract numerical columns from the DataFrame
    numerical_columns = df.select_dtypes(include=[np.number]).columns

    # Create a DataFrame with only numerical columns
    df_numerical = df[numerical_columns]

    # Standardize the data (optional but recommended for PCA)
    standardized_data = (df_numerical - df_numerical.mean()) / df_numerical.std()

    # Initialize PCA with the specified number of components
    pca = PCA(n_components=n_components)
    print(standardized_data.shape)
    # Fit and transform the data
    reduced_dimensions = pca.fit_transform(standardized_data)
    print(reduced_dimensions.shape)
    # Create a new DataFrame with reduced dimensions
    df_reduced = pd.DataFrame(reduced_dimensions, columns=[f'PC{i}' for i in range(1, n_components + 1)])
    print(df_reduced.shape)
    # Concatenate non-numerical columns (if any) with the reduced DataFrame
#     df_non_numerical = df.drop(columns=numerical_columns)
#     print(df_non_numerical.shape)
#     df_final = pd.concat([df_non_numerical, df_reduced], axis=1)
#     print(df_final.shape)
    return df_reduced

# %%
reduced_dimension_center_embeddings = apply_pca(center_embeddings,3)
reduced_dimension_right_embeddings = apply_pca(right_embeddings,3)
reduced_dimension_left_embeddings = apply_pca(left_embeddings, 3)
# Out:
# (692, 384)
# (692, 3)
# (692, 3)
# (997, 384)
# (997, 3)
# (997, 3)
# (994, 384)
# (994, 3)
# (994, 3)

# %%
reduced_dimension_center_embeddings
# Out:
#           PC1       PC2       PC3
# 0    1.034975  0.270528  1.334189
# 1    0.151234 -3.433094  4.613148
# 2   -1.077749  2.101952 -0.318197
# 3    0.988089  6.965502  2.168179
# 4    0.922125 -1.020294 -3.682009
# ..        ...       ...       ...
# 687  1.273218  1.849906  5.968518
# 688 -5.687350  2.323109 -4.637725
# 689  4.280162  4.977786 -0.205760
# 690  3.370911  4.830649 -0.019939
# 691 -6.803830  4.266058 -6.109500
#
# [692 rows x 3 columns]

# %%
reduced_dimension_right_embeddings
# Out:
#           PC1       PC2       PC3
# 0   -2.677349  6.474215  5.061068
# 1   -2.409129  4.087486 -7.354725
# 2    2.931601  3.908435 -9.241938
# 3    0.884223 -0.328901  0.545894
# 4    4.180972  2.038925  6.206781
# ..        ...       ...       ...
# 992 -0.567992  2.312587 -1.314967
# 993 -3.189203 -0.410055  3.919223
# 994 -3.141885 -7.028565 -2.293122
# 995 -0.826475  0.168275 -2.187477
# 996  4.199707 -4.350191 -0.298194
#
# [997 rows x 3 columns]

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

# Scatter plot for each DataFrame
ax.scatter(reduced_dimension_right_embeddings['PC1'], reduced_dimension_right_embeddings['PC2'], label='right', marker='o')
ax.scatter(reduced_dimension_center_embeddings['PC1'], reduced_dimension_center_embeddings['PC2'], label='center', marker='s')
ax.scatter(reduced_dimension_left_embeddings['PC1'], reduced_dimension_left_embeddings['PC2'], label='left', marker='^')

# Set labels and title
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
#ax.set_zlabel('Z-axis')
ax.set_title('3D Scatter Plot')

# Add legend
ax.legend()

# Show the plot
plt.show()

# %% [markdown]
# # Example

# %%
center_embeddings
# Out:
#             X0        X1        X2        X3        X4        X5        X6  \
# 0     0.007041 -0.030130 -0.044354 -0.016915  0.058667  0.034401 -0.100423
# 5    -0.022851  0.007856  0.013187 -0.001340  0.123223  0.045272  0.068733
# 8     0.035141 -0.036666 -0.001163 -0.002841  0.044225 -0.003311 -0.055538
# 17    0.003931  0.042187  0.128660  0.009664  0.028284 -0.022104  0.004893
# 19    0.061667  0.000966 -0.031503  0.066022  0.046642  0.105832  0.026858
# ...        ...       ...       ...       ...       ...       ...       ...
# 3625  0.034042  0.010349 -0.049296  0.048924  0.015843  0.047943  0.029442
# 3638  0.017933  0.038221  0.080240 -0.017855  0.014864 -0.039633  0.009735
# 3639  0.061735  0.077295  0.032443 -0.090068  0.072253  0.036361  0.018642
# 3650 -0.007028  0.140387 -0.031116  0.021637 -0.077028  0.007926  0.092987
# 3659 -0.071140  0.007851  0.004624 -0.034465  0.015566 -0.005315  0.126370
#
#             X7        X8        X9  ...      X375      X376      X377  \
# 0    -0.071921 -0.032756  0.018937  ...  0.056485  0.004152  0.011612
# 5     0.073309 -0.003106  0.097606  ...  0.011930 -0.079572 -0.039002
# 8    -0.073518  0.025240 -0.052999  ... -0.019099  0.058132 -0.071332
# 17   -0.044707  0.047454 -0.039734  ...  0.103595  0.036306 -0.051854
# 19   -0.032538  0.007044 -0.028047  ...  0.058648  0.050563  0.023688
# ...        ...       ...       ...  ...       ...       ...       ...
# 3625 -0.042356 -0.044982 -0.070646  ...  0.106159  0.063013 -0.052136
# 3638 -0.001002 -0.065782 -0.047231  ... -0.107203 -0.072108  0.021692
# 3639 -0.031543  0.061832  0.041081  ...  0.014073 -0.041122 -0.038077
# 3650 -0.066943  0.039499 -0.032581  ... -0.114163  0.040168  0.009158
# 3659 -0.024148 -0.057086 -0.031098  ...  0.024771 -0.042800 -0.008623
#
#           X378      X379      X380      X381      X382      X383    type
# 0     0.031171  0.070559  0.054114 -0.054441  0.059215  0.001551  center
# 5     0.060738 -0.037225  0.117596 -0.024066  0.067422  0.148397  center
# 8    -0.002137 -0.026079  0.053747  0.033268  0.112612  0.042738  center
# 17    0.015941  0.025386  0.009088  0.020265 -0.063742  0.050607  center
# 19   -0.014384 -0.006047  0.010739  0.039473  0.034189 -0.025969  center
# ...        ...       ...       ...       ...       ...       ...     ...
# 3625 -0.080917  0.019703  0.007190 -0.031549  0.020722 -0.009567  center
# 3638 -0.085258 -0.086258  0.035486 -0.004810  0.048264 -0.035154  center
# 3639 -0.067779 -0.029705  0.104989  0.015240 -0.042834  0.052302  center
# 3650 -0.012663 -0.016155 -0.047405 -0.082821 -0.040916  0.012911  center
# 3659 -0.025452 -0.033799  0.062373 -0.025695  0.103881 -0.023661  center
#
# [692 rows x 385 columns]

# %%
numerical_columns = [f'X{i}' for i in range(len(data_with_embeddings['embeddings'][0]))]

# %%
left_centeroid_vector = np.mean(left_embeddings[numerical_columns], axis = 0)
right_centroid_vector = np.mean(right_embeddings[numerical_columns], axis = 0)
center_centroid_vector = np.mean(center_embeddings[numerical_columns], axis = 0)
#generated_output = 'The president-elect is now taking a more aggressive stance on infrastructure, calling on the federal government to invest in infrastructure to help pay for infrastructure.'

# %%
left_centeroid_vector
# Out:
# X0      0.021455
# X1      0.021895
# X2      0.016067
# X3      0.009192
# X4      0.040284
#           ...
# X379   -0.008940
# X380    0.031650
# X381   -0.025273
# X382    0.029014
# X383    0.019281
# Length: 384, dtype: float64

# %%
right_centroid_vector
# Out:
# X0      0.016623
# X1      0.022426
# X2      0.009982
# X3      0.008744
# X4      0.039686
#           ...
# X379    0.000521
# X380    0.023649
# X381   -0.022566
# X382    0.025272
# X383    0.008644
# Length: 384, dtype: float64

# %%
center_centroid_vector
# Out:
# X0      0.010153
# X1      0.028588
# X2      0.005456
# X3      0.004331
# X4      0.035356
#           ...
# X379   -0.007271
# X380    0.026431
# X381   -0.032708
# X382    0.010078
# X383    0.016446
# Length: 384, dtype: float64

# %%
generated_text = " It’s a good thing that we are living in a time where we can’t have discussions about what we should do in a time of crisis. We’ll hear from the president on Monday and he’ll say things that will get very different from day one."

generated_text_embedding = model.encode(generated_text)
generated_text_embedding.shape
# Out:
# (384,)

# %%
generated_text_embedding
# Out:
# array([-2.83678453e-02, -3.30679752e-02,  5.57711683e-02, -6.05889633e-02,
#         2.84738969e-02, -1.34575297e-03,  1.09968958e-02,  1.16890781e-02,
#        -3.31867822e-02, -8.93947855e-02, -5.20521589e-02,  1.00616276e-01,
#        -3.71890329e-03,  2.53695026e-02,  5.50180525e-02,  2.38563735e-02,
#        -5.38921207e-02, -3.75938080e-02, -7.70244822e-02,  6.08548932e-02,
#         2.94945948e-02,  4.56617065e-02,  1.29156569e-02,  4.66545597e-02,
#        -9.69908237e-02,  5.77044897e-02,  2.30634399e-02,  2.34095324e-02,
#        -8.03880170e-02,  4.81588989e-02,  3.59132998e-02, -5.10117598e-02,
#        -6.88935593e-02, -1.48852905e-02,  2.56466717e-02,  1.77394822e-02,
#         5.09268865e-02,  1.44823231e-02,  8.54499042e-02, -1.20075673e-01,
#         5.73464297e-02,  3.46652158e-02, -1.26311462e-02, -2.66901311e-02,
#        -5.71112614e-03,  1.97048150e-02, -8.47671088e-03, -5.42242900e-02,
#         3.52035649e-02, -1.13164699e-02, -2.91613676e-02,  2.59987860e-06,
#        -4.58076261e-02, -1.07682392e-01,  8.70623142e-02,  8.66167769e-02,
#         6.12303847e-03,  2.73076128e-02,  6.19452707e-02, -2.96295006e-02,
#        -3.66655067e-02, -2.28387639e-02,  7.50968903e-02,  1.25376321e-03,
#        -1.04009360e-02, -1.09926816e-02, -1.62136238e-02,  4.00951393e-02,
#        -5.23348749e-02,  4.62708138e-02, -1.04341567e-01,  6.63806871e-02,
#         1.24020942e-01, -1.54885221e-02, -6.29942045e-02,  5.62113822e-02,
#         8.69217515e-02,  3.05157416e-02,  1.32479658e-02,  6.02609478e-02,
#         5.69076762e-02, -2.47803144e-02, -3.09041087e-02, -4.96305376e-02,
#        -4.74669077e-02,  1.67642124e-02, -7.20898658e-02,  3.10382843e-02,
#         5.28854840e-02,  6.64823130e-02,  1.30250216e-01,  8.52050856e-02,
#         2.91632414e-02, -4.01817448e-02,  1.41421268e-02, -2.27880152e-03,
#         2.69916728e-02,  2.28444906e-03, -6.94611520e-02,  3.33209671e-02],
#       dtype=float32)

# %%
distnace_from_right_centroid = np.linalg.norm(generated_text_embedding-right_centroid_vector)
distance_from_left_centroid = np.linalg.norm(generated_text_embedding - left_centeroid_vector)
distance_from_center_centroid = np.linalg.norm(generated_text_embedding - center_centroid_vector)

# %%
distnace_from_right_centroid
# Out:
# 0.9015740315791413

# %%
distance_from_left_centroid
# Out:
# 0.8828338688855593

# %%
distance_from_center_centroid
# Out:
# 0.9067427040520025

# %% [markdown]
# # New embeddings using articles

# %%
articles_data = pd.read_csv('./data/final_labels_MBIC.csv', sep =';')
# data_with_new_embeddings = data_df.copy()
# new_text_embedding = model.encode(list(data_df['text']))
articles_data['article'][0]
# Out:
# "YouTube says no ‘deepfakes’ or ‘birther’ videos with toughened 2020 election stance\nYouTube is making clear there will be no “birtherism” on its platform during this year’s U.S. presidential election – a belated response to a type of conspiracy theory more prevalent in the 2012 race.\nThe Google-owned video service is also reiterating that it won’t allow election-related “deepfake” videos and anything that aims to mislead viewers about voting procedures and how to participate in the 2020 census.\nYouTube clarified its rules ahead of the Iowa caucuses Monday. The company is mostly reiterating content guidelines that it has been putting in place since the last presidential election in 2016.\nIts ban on technically manipulated videos of political figures was made apparent last year when YouTube became the first major platform to remove a doctored video of House Speaker Nancy Pelosi. But the announcement Monday further clarifies that it will take down any election-related videos that are technically altered to mislead people in a way that goes beyond simply taking clips of speech out of context. The company also said it would remove doctored videos that could cause “serious risk of egregious harm” – such as to make it appear that a government official is dead.\n'Hey Google, show me photos': Google presents emotional 'Loretta' Super Bowl commercial\nFacebook: Sheryl Sandberg updates her relationship status with engagement announcement\nFacebook, which last year had resisted early calls to yank the Pelosi video, said in January that it was banning “deepfake” videos, the false but realistic clips created with artificial intelligence and sophisticated tools. Such videos are still fairly rare compared to simpler “cheap fake” manipulations such as were used in the video that altered Pelosi’s speech to make it seem like she was slurring her words.\nGoogle also said Monday that it will remove any videos that advance false claims about whether political candidates and elected officials are eligible to serve in office. That had been policy before, but wasn’t made explicit.\nThe company’s announcement comes about nine years after celebrity businessman Donald Trump began to get notice for claiming that Barack Obama, the nation’s first African American president, was not born in the United States.\nTrump repeatedly voiced citizenship doubts even after Obama produced his long-form birth certificate. Trump only fully backed off from the idea in the final stages of his 2016 presidential campaign.\nYouTube said it will also crack down on any attempts to artificially increase the number of views, likes and comments on videos. It changed its systems for recommending what videos users watch last year in a push to curb harmful misinformation. Twitter and Pinterest also last week outlined their efforts to reduce election misinformation on their platforms.\nMisinformation: Facebook, Google, YouTube and Twitter scramble to contain cororavirus misinformation\nDeepfakes: How to spot them on Facebook and YouTube ahead of the presidential election"

# %%
data_with_new_embeddings = articles_data.copy()
new_text_embedding = model.encode(list(articles_data['article']))
